# %%
import sys
import os
import requests

# %%
song = """Куплет 1  
Снег на гильзах тает в ранней весне,  
А в щели окопа — белая астра.  
Пальцы сжимают ружье в полусне,  
Но сердце шепчет: «Вырастет к утру».  
Цветок не метафора, он — как заряд,  
Что рвёт пустоту между страхом и болью.  
Окопный закат, и в дыму винегрет,  
И в каждом вздохе — обещанье быть сильным.  

Куплет 2  
Семена в кармане, как письма из пламени,  
Они не сгорели, хоть дом был в огне.  
Снежинки на почву — молитва о памяти,  
А в мыслях: «Прорастут под весной в борьбе».  
Ты помнишь, как брат говорил про цветы?  
«Они отгоняют смерть, как заклинанье».  
Теперь ты — его корни, его черты,  
И каждый всход — это голос в отчаянье."""

# %%
input = {
#  "callback_url": None,
 "title": "Военная песня 1",
 "tags": "Гитара, военное настрокение",
 "prompt": song
}

headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json',
    'Authorization': f'Bearer {os.getenv("GEN_API")}'
}

url_endpoint = "https://api.gen-api.ru/api/v1/networks/suno"
response = requests.post(url_endpoint, json=input, headers=headers)
print(response.json())

# %%
url_endpoint_answer = f"https://api.gen-api.ru/api/v1/request/get/{response.json()['request_id']}"
print(url_endpoint_answer)
# Out:
# https://api.gen-api.ru/api/v1/request/get/14685296

# %%
response_2 = requests.get(url_endpoint_answer, headers=headers)
print(response_2.json())
# Out:
# {'id': 14685296, 'status': 'success', 'response_type': 'audio', 'cost': 17, 'progress': 100, 'result': ['https://gen-api.storage.yandexcloud.net/input_files/1748470269_683789fdb9c8b.mp3', 'https://gen-api.storage.yandexcloud.net/input_files/1748470274_68378a02c11a6.mp3', {'video': None, 'image': 'https://gen-api.storage.yandexcloud.net/input_files/1748470284_68378a0c13ac2.jpeg'}, {'video': None, 'image': 'https://gen-api.storage.yandexcloud.net/input_files/1748470293_68378a1599a38.jpeg'}], 'full_response': [{'url': 'https://gen-api.storage.yandexcloud.net/input_files/1748470269_683789fdb9c8b.mp3'}, {'url': 'https://gen-api.storage.yandexcloud.net/input_files/1748470274_68378a02c11a6.mp3'}, {'video': None, 'image': 'https://gen-api.storage.yandexcloud.net/input_files/1748470284_68378a0c13ac2.jpeg'}, {'video': None, 'image': 'https://gen-api.storage.yandexcloud.net/input_files/1748470293_68378a1599a38.jpeg'}], 'parameters': {'mv': 'chirp-auk', 'tags': 'Guitar, military mood', 'model': 'v4.5', 'title': 'Military song 1', 'prompt': 'Куплет 1  \nСнег на гильзах тает в ранней весне,  \nА в щели окопа — белая астра.  \nПальцы сжимают ружье в полусне,  \nНо сердце шепчет: «Вырастет к утру».  \nЦветок не метафора, он — как заряд,  \nЧто рвёт пустоту между страхом и болью.  \nОкопный закат, и в дыму винегрет,  \nИ в каждом вздохе — обещанье быть сильным.  \n\nКуплет 2  \nСемена в кармане, как письма из пламени,  \nОни не сгорели, хоть дом был в огне.  \nСнежинки на почву — молитва о памяти,  \nА в мыслях: «Прорастут под весной в борьбе».  \nТы помнишь, как брат говорил про цветы?  \n«Они отгоняют смерть, как заклинанье».  \nТеперь ты — его корни, его черты,  \nИ каждый всход — это голос в отчаянье.', 'translate_input': True}}

# %% [markdown]
# ----------------------------

# %% [markdown]
# Отсмотрим полный процесс генерации

# %%
import sys
import os

src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
sys.path.append(src_path)


from agentsystem import AgentSystem

# %%
agent = AgentSystem(
        model="qwen/qwen3-235b-a22b:free",
        base_url="https://openrouter.ai/api/v1",
        api_key=os.getenv("OPENROUTEREGORGOOGLE"),
        temperature=0.7,
        top_p=0.8,
        api_key_image=os.getenv('FREEPIK_API'),
        api_key_song=os.getenv('GEN_API'),
        music=True
    )

story = "15 января 1945 года. Морозный ветер резал лицо, словно ножом, но лейтенант Михаил Петров не чувствовал холода. В госпитальной палате он держал в неповреждённой правой руке листок бумаги, готовясь написать письмо домой. Левая рука, перевязанная, лежала на груди — ранение, полученное два дня назад, не позволяло даже держать ручку. Но мысли его вновь и вновь возвращались к тому январскому утру, когда он стал героем. Его рота продвигалась через заснеженные поля Восточной Пруссии, где каждый сантиметр земли охраняли пулемёты и минные поля. Под прикрытием плотного огня Михаил заметил, как в разрушенной хате скрылись несколько немцев. Вместо того чтобы ждать поддержки, он бросился вперёд, пригибаясь к земле. Внутри оказалось семеро солдат и офицер — они дрожали, пытаясь согреться над крошечным костром. «Сдавайтесь!» — крикнул Михаил, держа автомат наперевес. Удивлённые, враги опустили оружие. Пленных увели, а он, не теряя времени, присоединился к наступлению. На следующий день, во время атаки на укреплённую деревню, осколок разорвавшегося снаряда задел его левую руку. «Кость цела, — сказал медик, — через месяц дома». Но Михаил знал: домой его путь лежит через подвиг. Он вернулся в строй, едва окрепнув, и вновь шёл вперёд, ведя солдат в бой. Когда в штабе узнали о его поимке вражеского офицера, командир похлопал по плечу: «Орден Славы тебе обеспечили». Михаил улыбнулся — не от гордости, а от мысли, что теперь сможет помочь семье. В письме он упомянул часы, оставленные в полку: «Продам, если нужны деньги». Но в душе мечтал, что награда станет для родителей символом — их сын не просто выжил, но сражался достойно. Поздним вечером он написал сестре Елизовете: «Не пугайтесь ранения. Я жив, и это главное. Расскажи, как у вас с хлебом? Здесь снег, как на Урале, но мы его пройдём. Обещаю». В ту ночь, глядя на окровавленный бинт, Михаил вспомнил, как в детстве мать говорила: «Смелость — не значит безумие. Это когда страх побеждаешь ради других». Теперь он знал: его смелость — в каждом шаге к победе, в каждом спасённом товарище, в каждом слове, отправляющем домой надежду. Героизм — не в отсутствии боли, а в умении идти сквозь неё. И когда в марте 1945 года орден Славы третей степени оказался на его груди, Михаил думал не о медали, а о том, что отец, потерявший руку на Первой мировой, увидит в нём продолжение рода солдатской чести."

# %%
response = agent.process_agent_system(query="Сделай историю более радостной", letter=story)
# Out:
# Эмоции:
# Куплет 1
# В госпитале стылый ветер за окном,
# Снег царапает стекло, как пулемётный шквал.
# Он пишет письмо — рука с повязкой живой,
# Светит солнечный луч, как улыбка родной.
# За спиной — воронки, в глазах — только снег,
# Но в сердечной тиши — дом, где пшеничный бег.
#
# Куплет 2
# В хате враги стояли, как в детстве снеговик,
# Он крикнул: «Руки вверх!» — и смолк боевой крик.
# «Danke» — шепнул юнец, не зная, что это дань,
# А Михаил вспомнил: «Смелость — душу не терять».
# Орден Славы не для славы, а для тех, кто ждёт,
# Шаг за шагом сквозь метель — домой, через лёд.
# {'request_id': 14687525, 'model': 'suno', 'status': 'processing'}
# Пока что в работе
# Пока что в работе
# Пока что в работе

# %%
print(response['history'])
# Out:
# **История**
#
# 15 января 1945 года. Михаил Петров сидел в госпитальной палате, прижимая к груди перевязанную левую руку. За окном Восточной Пруссии свирепствовал мороз, но в его сердце было тепло. «Живой», думал он, глядя на солнечный луч, пробившийся сквозь тучи. Такой же яркий, как улыбка сестры Лизы, которую он вспоминал, начиная письмо.
#
# Два дня назад он впервые почувствовал, как страх отступает перед долгом. Рота продвигалась сквозь снежные заносы, когда в разрушенной хате мелькнули немецкие мундиры. Вместо того чтобы ждать подкрепления, Михаил рванул вперёд, огибая воронки. Внутри — семеро врагов, растерянные, как дети. «Сдавайтесь!» — крикнул он, и пулемёты замолчали. Один из немцев, юнец не старше Лизы, опустил винтовку и прошептал: «Danke». Михаил не понял, но позже узнал — тот благодарил за жизнь.
#
# Ранение, полученное под деревней, оказалось легче, чем он опасался. «Кость цела», — обрадовал медик, и товарищи подарили ему кусок мороженого шоколада, найденного в трофейном рюкзаке. «Теперь ты не просто герой, а сладкий герой», — засмеялся старшина, и смех этот, несмотря на войну, пронёсся по госпиталю, как весенний ветер. Михаил знал: нельзя терять времени. Уже через неделю, прихрамывая, он вернулся к своим.
#
# Когда командир вручил ему орден Славы, Михаил вспомнил отца — молчаливого фронтовика Первой мировой, который никогда не хвастался своими наградами. «Теперь у тебя есть своя честь», — сказал отец в прощальном письме. А Михаил думал о матери: как она, сидя у печки, штопала ему носки, повторяя: «Смелость — это когда страх побеждаешь, но не теряешь душу».
#
# В марте, в перерыве между боями, он написал Лизе: «Представляю, как вы с папой ругаете меня за часы — продам, если нужно. Но знайте: я жив, и каждый день здесь — шаг к вам. Помнишь, как мы в детстве лепили снеговика из сугробов, что выше нас были? Теперь я леплю победу, кусок за куском. Скоро домой!»
#
# Товарищи звали его «ледяным храбрецом», ведь в ту хату он ворвался, будто снежная метель, сметающая всё на пути. А он лишь улыбался, глядя на орден — не как на знак славы, а как на обещание. Обещание, что его семья увидит в нём не раны, а свет, который он нес даже сквозь тьму войны.
#
# Когда в штабе спросили: «Почему вернулся в строй?», Михаил ответил: «Потому что смеялись над снегом. И я не могу оставить их смеяться одним». Его рота знала — за этим лейтенантом идти легко. Он не просто вёл, он дарил веру: в себя, в товарища, в то, что за снегами Восточной Пруссии уже маячит дом, где вместо минных полей — пшеничные поля, а вместо выстрелов — звон колоколов.
#
# Героизм Михаила был не в безрассудстве, а в каждом шаге, который он делал, чтобы увидеть улыбки тех, кого любил. И в каждом «живой» — и для себя, и для тех, кто ждал его.

# %%
print(response['url_pic'])

# %%
print(response['url_music'])
